# %% [markdown]
# <a href="https://colab.research.google.com/github/realyou0312/KPS_keyword_project/blob/main/test_algorithm_Noel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
import pandas as pd
import time

header = {'Authorization':'Basic {ZTY1MTAzOTc4MWZjNDg2OTgyNDQ2NDcyMGEzMjQ3M2M6MWNjYjUxYjdiZmIwNTdhMDJjYTllMGIyZmVjZmRlNmFiZjM0YjVkZDlhZTk2YjQ3Y2QwYzIwZTRkMWEyODRiZA==}'}

# %%
mode = input("1: 농심 2: 오뚜기 3: SK하이닉스 4: 현대차 5 : LG디스플레이")

if mode == '1':
    path = '/content/drive/MyDrive/KAKAOPAYSEC/data2/농심.csv'
    name = '농심'
elif mode == '2':
    path = '/content/drive/MyDrive/KAKAOPAYSEC/data2/오뚜기.csv'
    name = '오뚜기'

elif mode == '3':
    path = '/content/drive/MyDrive/KAKAOPAYSEC/data2/SK하이닉스.csv'
    name = 'SK하이닉스'

elif mode == '4':
    path = '/content/drive/MyDrive/KAKAOPAYSEC/data2/현대차.csv'
    name = '현대자동차'

else:
    path = '/content/drive/MyDrive/KAKAOPAYSEC/data2/LG디스플레이.csv'
    name = 'LG디스플레이'

df = pd.read_csv(path, encoding='utf-8')
data_list = df.values.tolist()
# Out:
# 1: 농심 2: 오뚜기 3: SK하이닉스 4: 현대차 5 : LG디스플레이1

# %%
def web_request(method_name, url, is_urlencoded=True, timeout_seconds=3):
    """Web GET or POST request를 호출 후 그 결과를 dict형으로 반환 """
    method_name = method_name.upper() # 메소드이름을 대문자로 바꾼다 
    if method_name not in ('GET', 'POST'):
        raise Exception('method_name is GET or POST plz...')
        
    if method_name == 'GET': # GET방식인 경우
        response = requests.get(url=url, timeout=timeout_seconds)
    elif method_name == 'POST': # POST방식인 경우
        if is_urlencoded is True:
            response = requests.post(url=url, \
                                     timeout=timeout_seconds, headers=header)
        else:
            response = requests.post(url=url, \
                                     timeout=timeout_seconds, headers=header)
    return response
    
def web_request_retry(num_retry=3, sleep_seconds=1, **kwargs):
    """timeout발생 시 sleep_seconds쉬고 num_retyrp번 재시도 한다"""
    for n in range(num_retry):
        try:
            return web_request(**kwargs)
        except requests.exceptions.Timeout:
            print(str(n+1) + ' Timeout')
            time.sleep(sleep_seconds)
            continue
    return None

# %%
keywords = []
for data in data_list:
    # data[0] : 인물 data[1] : 브랜드 data[3] : 임직원 data[4] : 주주

    person = data[0]
    if not pd.isna(person):
        print(person + "!!!!!!")
        url_company = f'https://api.deepsearch.com/v1/compute?input=DocumentAggregation("news","economy","{person}","named_entities.entities.company.name:100",date_from=2020-01-01)'
        res_company = requests.post(url_company, headers=header,)
        company_data = res_company.json()

        print(f"{person} DATA LOADING !!!!")
        len_company = len(company_data['data']['pods'][1]['content']['data']['key'])
        if len_company != 0:
            related_company = company_data['data']['pods'][1]['content']['data']['key'][0]

            if related_company == name:
                keyword = "1_" + person
                print("keyword : "  + keyword + " !!!!!!")
                keywords.append(keyword)

            print("PERSON END !!!!")
            time.sleep(5)

    brand = data[1]

    if not pd.isna(brand):

        print(brand + "!!!!!!!!!")

        url_company = f'https://api.deepsearch.com/v1/compute?input=DocumentAggregation("news","economy","{brand}","named_entities.entities.company.name:100",date_from=2020-01-01)'
        res_company = requests.post(url_company, headers=header)
        company_data = res_company.json()

        print(f"{brand} DATA LOADING !!!!")
        len_company = len(company_data['data']['pods'][1]['content']['data']['key'])
        if len_company != 0:

            related_company = company_data['data']['pods'][1]['content']['data']['key'][0]

            if related_company == name:
                keyword = "2_" + brand
                print("keyword : " + keyword + " !!!!!!")
                keywords.append(keyword)

            print("BRAND END !!!!")
            time.sleep(5)

    ceo = data[2]
    if not pd.isna(ceo):
        print(ceo + "!!!!!!!!!")

        url_company = f'https://api.deepsearch.com/v1/compute?input=DocumentAggregation("news","economy","{ceo}","named_entities.entities.company.name:100",date_from=2020-01-01)'
        res_company = requests.post(url_company, headers=header)
        company_data = res_company.json()

        print(f"{ceo} DATA LOADING !!!!")

        len_company = len(company_data['data']['pods'][1]['content']['data']['key'])
        if len_company != 0:
            related_company = company_data['data']['pods'][1]['content']['data']['key'][0]

            if related_company == name:
                keyword = "3_" + ceo
                print("keyword : " + keyword + " !!!!!!")
                keywords.append(keyword)

            print("CEO END !!!!")
            time.sleep(5)

    stock_holder = data[3]
    if not pd.isna(stock_holder):
        print(stock_holder + "!!!!!!!!!")

        url_company = f'https://api.deepsearch.com/v1/compute?input=DocumentAggregation("news","economy","{stock_holder}","named_entities.entities.company.name:100",date_from=2020-01-01)'
        res_company = requests.post(url_company, headers=header)
        company_data = res_company.json()

        print(f"{stock_holder} DATA LOADING !!!!")
        len_company = len(company_data['data']['pods'][1]['content']['data']['key'])
        if len_company != 0:

            related_company = company_data['data']['pods'][1]['content']['data']['key'][0]

            if related_company == name:
                keyword = "4_" + stock_holder
                print("keyword : " + keyword + " !!!!!!")
                keywords.append(keyword)

            print("BRAND END !!!!")
            time.sleep(5)

for keyword in keywords:
    print(keyword)
# Out:
# 문재인!!!!!!
# 문재인 DATA LOADING !!!!
# PERSON END !!!!
# 힐스테이트!!!!!!!!!
# 힐스테이트 DATA LOADING !!!!
# BRAND END !!!!
# 박정호!!!!!!!!!
# 박정호 DATA LOADING !!!!
# CEO END !!!!
# SK텔레콤(주)!!!!!!!!!
# SK텔레콤(주) DATA LOADING !!!!
# BRAND END !!!!
# 서상영!!!!!!
# 서상영 DATA LOADING !!!!
# PERSON END !!!!
# 뉴시스!!!!!!!!!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-bada2c833693> in <module>()
#      31
#      32         url_company = f'https://api.deepsearch.com/v1/compute?input=DocumentAggregation("news","economy","{brand}","named_entities.entities.company.name:100",date_from=2020-01-01)'
# ---> 33         res_company = requests.post(url_company, headers=header)
#      34         company_data = res_company.json()
#      35
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# ...

# %%
keywords
# Out:
# []

# %%
keywords2 = []
for data in data_list:
    # data[0] : 인물 data[1] : 브랜드 data[3] : 임직원 data[4] : 주주

    person = data[0]


    if not pd.isna(person):
      if '&' in person:
        person = person.replace('&','%26')

      print(person + "!!!!!!")
      url_company = f'https://api.deepsearch.com/v1/compute?input=DocumentAggregation("news","economy","{person}","named_entities.entities.company.name:100",date_from=2020-01-01)'
      res_company = requests.post(url_company, headers=header)
      company_data = res_company.json()

      print(f"{person} DATA LOADING !!!!")
      len_company = len(company_data['data']['pods'][1]['content']['data']['key'])
      if len_company != 0:
          related_company = company_data['data']['pods'][1]['content']['data']['key'][0]

          if related_company == name:
              keyword = "1_" + person
              print("keyword : "  + keyword + " !!!!!!")
              keywords2.append(keyword)

      print("PERSON END !!!!")
      time.sleep(5)

    brand = data[1]


    if not pd.isna(brand):
      if '&' in brand:
        brand = brand.replace('&','%26')
      print(brand + "!!!!!!!!!")

      url_company = f'https://api.deepsearch.com/v1/compute?input=DocumentAggregation("news","economy","{brand}","named_entities.entities.company.name:100",date_from=2020-01-01)'
      res_company = requests.post(url_company, headers=header)
      company_data = res_company.json()

      print(f"{brand} DATA LOADING !!!!")
      len_company = len(company_data['data']['pods'][1]['content']['data']['key'])
      if len_company != 0:

          related_company = company_data['data']['pods'][1]['content']['data']['key'][0]

          if related_company == name:
              keyword = "2_" + brand
              print("keyword : " + keyword + " !!!!!!")
              keywords2.append(keyword)

      print("BRAND END !!!!")
      time.sleep(5)

    ceo = data[2]

    if not pd.isna(ceo):
      print(ceo + "!!!!!!!!!")
      if '&' in ceo:
        ceo = ceo.replace('&','%26')
      url_company = f'https://api.deepsearch.com/v1/compute?input=DocumentAggregation("news","economy","{ceo}","named_entities.entities.company.name:100",date_from=2020-01-01)'
      res_company = requests.post(url_company, headers=header)
      company_data = res_company.json()

      print(f"{ceo} DATA LOADING !!!!")

      len_company = len(company_data['data']['pods'][1]['content']['data']['key'])
      if len_company != 0:
          related_company = company_data['data']['pods'][1]['content']['data']['key'][0]

          if related_company == name:
              keyword = "3_" + ceo
              print("keyword : " + keyword + " !!!!!!")
              keywords2.append(keyword)

      print("CEO END !!!!")
      time.sleep(5)

    stock_holder = data[3]

    if not pd.isna(stock_holder):
      print(stock_holder + "!!!!!!!!!")

      if '&' in stock_holder:
        stock_holder = stock_holder.replace('&','%26')
      url_company = f'https://api.deepsearch.com/v1/compute?input=DocumentAggregation("news","economy","{stock_holder}","named_entities.entities.company.name:100",date_from=2020-01-01)'
      res_company = requests.post(url_company, headers=header)
      company_data = res_company.json()

      print(f"{stock_holder} DATA LOADING !!!!")
      len_company = len(company_data['data']['pods'][1]['content']['data']['key'])
      if len_company != 0:

        related_company = company_data['data']['pods'][1]['content']['data']['key'][0]

        if related_company == name:
          keyword = "4_" + stock_holder
          print("keyword : " + keyword + " !!!!!!")
          keywords2.append(keyword)

      print("BRAND END !!!!")
      time.sleep(5)

for keyword in keywords2:
    print(keyword)

# %%
keywords2

# %%
keywords3 = []
for data in data_list:
    # data[0] : 인물 data[1] : 브랜드 data[3] : 임직원 data[4] : 주주

    person = data[0]


    if not pd.isna(person):
      if '&' in person:
        person = person.replace('&','%26')

      print(person + "!!!!!!")
      url_company = f'https://api.deepsearch.com/v1/compute?input=DocumentAggregation("news","economy","{person}","named_entities.entities.company.name:100",date_from=2020-01-01)'
      res_company = web_request_retry(method_name='POST', url=url_company, is_urlencoded=True, num_retry=5 )
      company_data = res_company.json()

      print(f"{person} DATA LOADING !!!!")
      len_company = len(company_data['data']['pods'][1]['content']['data']['key'])
      if len_company != 0:
          related_company = company_data['data']['pods'][1]['content']['data']['key'][0]

          if related_company == name:
              keyword = "1_" + person
              print("keyword : "  + keyword + " !!!!!!")
              keywords3.append(keyword)

      print("PERSON END !!!!")

    brand = data[1]


    if not pd.isna(brand):
      if '&' in brand:
        brand = brand.replace('&','%26')
      print(brand + "!!!!!!!!!")

      url_company = f'https://api.deepsearch.com/v1/compute?input=DocumentAggregation("news","economy","{brand}","named_entities.entities.company.name:100",date_from=2020-01-01)'
      res_company = web_request_retry(method_name='POST', url=url_company, is_urlencoded=True, num_retry=5 )
      company_data = res_company.json()

      print(f"{brand} DATA LOADING !!!!")
      len_company = len(company_data['data']['pods'][1]['content']['data']['key'])
      if len_company != 0:

          related_company = company_data['data']['pods'][1]['content']['data']['key'][0]

          if related_company == name:
              keyword = "2_" + brand
              print("keyword : " + keyword + " !!!!!!")
              keywords3.append(keyword)

      print("BRAND END !!!!")

    ceo = data[2]

    if not pd.isna(ceo):
      print(ceo + "!!!!!!!!!")
      if '&' in ceo:
        ceo = ceo.replace('&','%26')
      url_company = f'https://api.deepsearch.com/v1/compute?input=DocumentAggregation("news","economy","{ceo}","named_entities.entities.company.name:100",date_from=2020-01-01)'
      res_company = web_request_retry(method_name='POST', url=url_company, is_urlencoded=True, num_retry=5 )
      company_data = res_company.json()

      print(f"{ceo} DATA LOADING !!!!")

      len_company = len(company_data['data']['pods'][1]['content']['data']['key'])
      if len_company != 0:
          related_company = company_data['data']['pods'][1]['content']['data']['key'][0]

          if related_company == name:
              keyword = "3_" + ceo
              print("keyword : " + keyword + " !!!!!!")
              keywords3.append(keyword)

      print("CEO END !!!!")

    stock_holder = data[3]

    if not pd.isna(stock_holder):
      print(stock_holder + "!!!!!!!!!")

      if '&' in stock_holder:
        stock_holder = stock_holder.replace('&','%26')
      url_company = f'https://api.deepsearch.com/v1/compute?input=DocumentAggregation("news","economy","{stock_holder}","named_entities.entities.company.name:100",date_from=2020-01-01)'
      res_company = web_request_retry(method_name='POST', url=url_company, is_urlencoded=True, num_retry=5 )
      company_data = res_company.json()

      print(f"{stock_holder} DATA LOADING !!!!")
      len_company = len(company_data['data']['pods'][1]['content']['data']['key'])
      if len_company != 0:

        related_company = company_data['data']['pods'][1]['content']['data']['key'][0]

        if related_company == name:
          keyword = "4_" + stock_holder
          print("keyword : " + keyword + " !!!!!!")
          keywords3.append(keyword)

      print("STOCK_HOLDER END !!!!")


for keyword in keywords3:
    print(keyword)
# Out:
# 문재인!!!!!!
# 문재인 DATA LOADING !!!!
# PERSON END !!!!
# 새우깡!!!!!!!!!
# 새우깡 DATA LOADING !!!!
# keyword : 2_새우깡 !!!!!!
# BRAND END !!!!
# 신동원!!!!!!!!!
# 신동원 DATA LOADING !!!!
# keyword : 3_신동원 !!!!!!
# CEO END !!!!
# (주)농심홀딩스!!!!!!!!!
# (주)농심홀딩스 DATA LOADING !!!!
# keyword : 4_(주)농심홀딩스 !!!!!!
# STOCK_HOLDER END !!!!
# 방탄소년단!!!!!!
# 방탄소년단 DATA LOADING !!!!
# PERSON END !!!!
# 짜파게티!!!!!!!!!
# 짜파게티 DATA LOADING !!!!
# keyword : 2_짜파게티 !!!!!!
# BRAND END !!!!
# 박준!!!!!!!!!
# 박준 DATA LOADING !!!!
# keyword : 3_박준 !!!!!!
# CEO END !!!!
# 국민연금공단!!!!!!!!!
# 국민연금공단 DATA LOADING !!!!
# STOCK_HOLDER END !!!!
# 음문석!!!!!!
# 음문석 DATA LOADING !!!!
# keyword : 1_음문석 !!!!!!
# PERSON END !!!!
# 짜파구리!!!!!!!!!
# 짜파구리 DATA LOADING !!!!
# keyword : 2_짜파구리 !!!!!!
# BRAND END !!!!
# 이영진!!!!!!!!!
# 이영진 DATA LOADING !!!!
# keyword : 3_이영진 !!!!!!
# CEO END !!!!
# (재)율촌재단!!!!!!!!!
# (재)율촌재단 DATA LOADING !!!!
# keyword : 4_(재)율촌재단 !!!!!!
# STOCK_HOLDER END !!!!
# 위아래!!!!!!
# 위아래 DATA LOADING !!!!
# PERSON END !!!!
# ...

# %%
keywords3 = []
for data in data_list:
    # data[0] : 인물 data[1] : 브랜드 data[3] : 임직원 data[4] : 주주

    # person = data[0]


    # if not pd.isna(person):
    #   if '&' in person:
    #     person = person.replace('&','%26')

    #   print(person + "!!!!!!")
    #   url_company = f'https://api.deepsearch.com/v1/compute?input=DocumentAggregation("news","economy","{person}","named_entities.entities.company.name:100",date_from=2020-01-01)'
    #   res_company = web_request_retry(method_name='POST', url=url_company, is_urlencoded=True, num_retry=5 )
    #   company_data = res_company.json()

    #   print(f"{person} DATA LOADING !!!!")
    #   len_company = len(company_data['data']['pods'][1]['content']['data']['key'])
    #   if len_company != 0:
    #       related_company = company_data['data']['pods'][1]['content']['data']['key'][0]

    #       if related_company == name:
    #           keyword = "1_" + person
    #           print("keyword : "  + keyword + " !!!!!!")
    #           keywords3.append(keyword)

    #   print("PERSON END !!!!")

    brand = data[1]


    if not pd.isna(brand):
      if '&' in brand:
        brand = brand.replace('&','%26')
      print(brand + "!!!!!!!!!")

      url_company = f'https://api.deepsearch.com/v1/compute?input=DocumentAggregation("news","economy","{brand}",date_from=2010-01-01)'
      res_company = web_request_retry(method_name='POST', url=url_company, is_urlencoded=True, num_retry=5 )
      company_data = res_company.json()

      print(f"{brand} DATA LOADING !!!!")
      len_company = len(company_data['data']['pods'][1]['content']['data']['key'])
      if len_company != 0:

          related_company = company_data['data']['pods'][1]['content']['data']['key'][0]

          if related_company == name:
              keyword = "2_" + brand
              print("keyword : " + keyword + " !!!!!!")
              keywords3.append(keyword)

      print("BRAND END !!!!")

    # ceo = data[2]

    # if not pd.isna(ceo):
    #   print(ceo + "!!!!!!!!!")
    #   if '&' in ceo:
    #     ceo = ceo.replace('&','%26')
    #   url_company = f'https://api.deepsearch.com/v1/compute?input=DocumentAggregation("news","economy","{ceo}","named_entities.entities.company.name:100",date_from=2020-01-01)'
    #   res_company = web_request_retry(method_name='POST', url=url_company, is_urlencoded=True, num_retry=5 )
    #   company_data = res_company.json()

    #   print(f"{ceo} DATA LOADING !!!!")

    #   len_company = len(company_data['data']['pods'][1]['content']['data']['key'])
    #   if len_company != 0:
    #       related_company = company_data['data']['pods'][1]['content']['data']['key'][0]

    #       if related_company == name:
    #           keyword = "3_" + ceo
    #           print("keyword : " + keyword + " !!!!!!")
    #           keywords3.append(keyword)

    #   print("CEO END !!!!")

    # stock_holder = data[3]

    # if not pd.isna(stock_holder):
    #   print(stock_holder + "!!!!!!!!!")

    #   if '&' in stock_holder:
    #     stock_holder = stock_holder.replace('&','%26')
    #   url_company = f'https://api.deepsearch.com/v1/compute?input=DocumentAggregation("news","economy","{stock_holder}","named_entities.entities.company.name:100",date_from=2020-01-01)'
    #   res_company = web_request_retry(method_name='POST', url=url_company, is_urlencoded=True, num_retry=5 )
    #   company_data = res_company.json()

    #   print(f"{stock_holder} DATA LOADING !!!!")
    #   len_company = len(company_data['data']['pods'][1]['content']['data']['key'])
    #   if len_company != 0:

    #     related_company = company_data['data']['pods'][1]['content']['data']['key'][0]

    #     if related_company == name:
    #       keyword = "4_" + stock_holder
    #       print("keyword : " + keyword + " !!!!!!")
    #       keywords3.append(keyword)

    #   print("STOCK_HOLDER END !!!!")


for keyword in keywords3:
    print(keyword)
# Out:
# 새우깡!!!!!!!!!
# 새우깡 DATA LOADING !!!!
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-48c7e63eb5ef> in <module>()
#      40
#      41       print(f"{brand} DATA LOADING !!!!")
# ---> 42       len_company = len(company_data['data']['pods'][1]['content']['data']['key'])
#      43       if len_company != 0:
#      44
#
# IndexError: list index out of range
